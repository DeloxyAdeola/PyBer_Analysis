# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.5.1'

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')

# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 and 45.
plt.ylim(0, 45)

# Create a title.
plt.title("PyBer Fare by Month")

# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="d", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(2, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
fig, ax = plt.subplots()

#Change the bar color to cyan.
ax.barh(x_axis, y_axis, color="Cyan" , label='Chicago')
# labels read top-to-bottom
ax.invert_yaxis()
#Switch the axis so that the Fare($) data is on the x-axis.
ax.set_xlabel('Fare($)')
ax.set_ylabel('Date')
#Add a title and axes labels.
ax.set_title('PyBer Fare by Month')

plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis)

# %%
#Switch the axis so that the Fare($) data is on the x-axis.
plt.scatter(y_axis, x_axis, color='red', marker='x', label='Chicago')
#Add a title and axes labels.
plt.xlabel('Fare($)')
plt.ylabel('Date')
#Add a title and axes labels.
plt.title('PyBer Fare by Month')
#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()
#Add a limit for the x-axis data.
plt.xlim(0,50)
#Add a legend for the city of Chicago.
plt.legend()
plt.show()

# %%
#Switch the axis so that the Fare($) data is on the x-axis.
plt.scatter(y_axis, x_axis, color='red', marker='x', label='Chicago')
#Add a title and axes labels.
plt.xlabel('Fare($)')
plt.ylabel('Date')
#Add a title and axes labels.
plt.title('PyBer Fare by Month')
#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()
#Add a limit for the x-axis data.
plt.xlim(0,50)
#Add a legend for the city of Chicago.
plt.legend()
plt.show()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
#you can use list comprehension to replace many for and while loops.
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
#let's make one using the object-oriented approach.
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()

#Change the bar color to cyan.
ax.barh(x_axis, y_axis, color="Cyan" , label='Chicago')
# labels read top-to-bottom
ax.invert_yaxis()
#Switch the axis so that the Fare($) data is on the x-axis.
ax.set_xlabel('Fare($)')
ax.set_ylabel('Date')
#Add a title and axes labels.
ax.set_title('PyBer Fare by Month')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [119], in <cell line: 1>()
# ----> 1 fig, ax = plt.subplots
#       2 ax.scatter(y_axis, x_axis, color='red', marker='x', label='Chicago')
#       3 ax.set_title('PyBer Fare by Month')
#
# TypeError: cannot unpack non-iterable function object

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21a2ed3dd90>,
#   <matplotlib.patches.Wedge at 0x21a2ed52940>,
#   <matplotlib.patches.Wedge at 0x21a2ed52280>,
#   <matplotlib.patches.Wedge at 0x21a2ed30f40>,
#   <matplotlib.patches.Wedge at 0x21a2ed306d0>,
#   <matplotlib.patches.Wedge at 0x21a2ed30ee0>,
#   <matplotlib.patches.Wedge at 0x21a2ed5b6d0>,
#   <matplotlib.patches.Wedge at 0x21a2ed5b700>,
#   <matplotlib.patches.Wedge at 0x21a2ecda460>,
#   <matplotlib.patches.Wedge at 0x21a2ecdae20>,
#   <matplotlib.patches.Wedge at 0x21a2ed3df10>,
#   <matplotlib.patches.Wedge at 0x21a2ec82ac0>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21a2ce9d2e0>,
#   <matplotlib.patches.Wedge at 0x21a2eb82430>,
#   <matplotlib.patches.Wedge at 0x21a2eb82f70>,
#   <matplotlib.patches.Wedge at 0x21a29984310>,
#   <matplotlib.patches.Wedge at 0x21a2cea4b20>,
#   <matplotlib.patches.Wedge at 0x21a2cea46d0>,
#   <matplotlib.patches.Wedge at 0x21a29a55af0>,
#   <matplotlib.patches.Wedge at 0x21a29a553d0>,
#   <matplotlib.patches.Wedge at 0x21a2e7fcca0>,
#   <matplotlib.patches.Wedge at 0x21a2e7fc760>,
#   <matplotlib.patches.Wedge at 0x21a2ca3b970>,
#   <matplotlib.patches.Wedge at 0x21a2ca35280>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
explode=explode_values,
colors=colors,
labels=x_axis,
autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21a31dc62b0>,
#   <matplotlib.patches.Wedge at 0x21a31dc68b0>,
#   <matplotlib.patches.Wedge at 0x21a31dc6fd0>,
#   <matplotlib.patches.Wedge at 0x21a31dd4730>,
#   <matplotlib.patches.Wedge at 0x21a31dd4e50>,
#   <matplotlib.patches.Wedge at 0x21a31de05b0>,
#   <matplotlib.patches.Wedge at 0x21a31de0cd0>,
#   <matplotlib.patches.Wedge at 0x21a31dec430>,
#   <matplotlib.patches.Wedge at 0x21a31decb50>,
#   <matplotlib.patches.Wedge at 0x21a31dfa2b0>,
#   <matplotlib.patches.Wedge at 0x21a31dfa9d0>,
#   <matplotlib.patches.Wedge at 0x21a31e06130>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.5907474957304654, 1.1580230551626267, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.36353692044951713, 0.7126295724077703, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
colors = ["slateblue", "magenta", "darkred", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "green", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()
ax.invert_xaxis()
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
explode=explode_values, shadow=True,
colors=colors, startangle=90,
labels=x_axis,
autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x21a31fd16a0>,
#   <matplotlib.patches.Wedge at 0x21a31fd1f10>,
#   <matplotlib.patches.Wedge at 0x21a31fe08e0>,
#   <matplotlib.patches.Wedge at 0x21a31fed2b0>,
#   <matplotlib.patches.Wedge at 0x21a31fedc40>,
#   <matplotlib.patches.Wedge at 0x21a31ffb610>,
#   <matplotlib.patches.Wedge at 0x21a31ffbfa0>,
#   <matplotlib.patches.Wedge at 0x21a3200a970>,
#   <matplotlib.patches.Wedge at 0x21a32017340>,
#   <matplotlib.patches.Wedge at 0x21a32017cd0>,
#   <matplotlib.patches.Wedge at 0x21a320246a0>,
#   <matplotlib.patches.Wedge at 0x21a32031070>],
#  [Text(-0.11437852557419109, 1.0940372721655667, 'Jan'),
#   Text(-0.4784051609753621, 0.9905193092273054, 'Feb'),
#   Text(-1.1580230551626267, 0.5907474957304655, 'Mar'),
#   Text(-1.0495504101751, -0.3293082697128625, 'April'),
#   Text(-0.5864693241605259, -0.930620079204557, 'May'),
#   Text(0.06046434452452751, -1.0983369533258995, 'June'),
#   Text(0.9249785389235743, -0.9134630274569462, 'July'),
#   Text(1.0749559354406817, -0.233387525075462, 'Aug'),
#   Text(1.099797660024518, 0.021097559209412683, 'Sept'),
#   Text(0.9987473359504124, 0.46098129998076287, 'Oct'),
#   Text(0.6507384104340304, 0.886870633850164, 'Nov'),
#   Text(0.22807646384834382, 1.0760953148482877, 'Dec')],
#  [Text(-0.062388286676831495, 0.5967476029993999, '3.3%'),
#   Text(-0.2609482696229248, 0.5402832595785301, '7.7%'),
#   Text(-0.7126295724077703, 0.36353692044951713, '13.0%'),
#   Text(-0.5724820419136909, -0.17962269257065225, '11.7%'),
#   Text(-0.3198923586330141, -0.5076109522933947, '10.7%'),
#   Text(0.032980551558833185, -0.5990928836323088, '8.9%'),
#   Text(0.5692175624145073, -0.5621310938196592, '14.5%'),
#   Text(0.5863396011494626, -0.12730228640479743, '3.5%'),
#   Text(0.5998896327406462, 0.011507759568770553, '3.9%'),
#   Text(0.5447712741547703, 0.2514443454440524, '9.2%'),
#   Text(0.3549482238731074, 0.4837476184637257, '6.9%'),
#   Text(0.12440534391727844, 0.5869610808263387, '6.6%')])
